# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('zips.csv')
df2 = pd.read_csv('plans.csv')
df3 = pd.read_csv('slcsp.csv')

# %% [markdown]
# ### Zip Codes

# %%
df1.head()
# Out:
#    zipcode state  county_code     name  rate_area
# 0    36749    AL         1001  Autauga         11
# 1    36703    AL         1001  Autauga         11
# 2    36003    AL         1001  Autauga         11
# 3    36008    AL         1001  Autauga         11
# 4    36006    AL         1001  Autauga         11

# %% [markdown]
# ### Plans

# %%
df2.head()
# Out:
#           plan_id state metal_level    rate  rate_area
# 0  74449NR9870320    GA      Silver  298.62          7
# 1  26325VH2723968    FL      Silver  421.43         60
# 2  09846WB8636633    IL        Gold  361.69          5
# 3  78590JQ3204809    SC        Gold  379.97          2
# 4  21163YD2193896    AR        Gold  359.75          2

# %% [markdown]
# ### SLCSP

# %%
df3.head()
# Out:
#    zipcode  rate
# 0    64148   NaN
# 1    67118   NaN
# 2    40813   NaN
# 3    18229   NaN
# 4    51012   NaN

# %%
for row in df1:
    print(row)
# Out:
# zipcode
# state
# county_code
# name
# rate_area

# %%
# Out:
#   File "<ipython-input-14-2a5641744cbb>", line 1
#     df1[df1['state'] == 'GA']df1['rate_area'] == 7
#                                ^
# SyntaxError: invalid syntax

# %%
df2[df2['metal_level'] == 'Silver']
# Out:
#               plan_id state metal_level        rate  rate_area
# 0      74449NR9870320    GA      Silver  298.620000          7
# 1      26325VH2723968    FL      Silver  421.430000         60
# 5      36956VI7724021    TX      Silver  310.120000         11
# 12     72190DW3284384    AZ      Silver  353.370000          4
# 17     22521KG6880321    GA      Silver  285.760000         13
# 18     52890CP9247848    PA      Silver  264.460000          5
# 19     71371IL9623602    WI      Silver  348.730000         11
# 20     82206LV3597031    MI      Silver  321.990000          6
# 21     25775GT9423594    MT      Silver  262.930000          1
# 22     65128VB5535475    SC      Silver  266.620000         25
# 24     66347PV5658737    MI      Silver  361.075153          4
# 26     63200WG1022541    AZ      Silver  479.870000          3
# 27     33663BA5215273    SC      Silver  313.690000          2
# 31     18967OW9854153    OH      Silver  417.280000         13
# ...
